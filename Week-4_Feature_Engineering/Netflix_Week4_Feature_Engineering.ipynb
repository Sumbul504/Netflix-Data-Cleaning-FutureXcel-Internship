# %% [markdown]
# # **Dataset Load**

# %%
import pandas as pd

df = pd.read_csv("/content/cleaned_netflix_data (4).csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                      Not Available        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25        2020.0  PG-13     90 min
# 1  2021-09-24        2021.0  TV-MA  2 Seasons
# 2  2021-09-24        2021.0  TV-MA   1 Season
# 3  2021-09-24        2021.0  TV-MA   1 Season
# 4  2021-09-24        2021.0  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# # **FEATURE ENGINEERING**

# %% [markdown]
# **Content Age**

# %%
current_year = 2024
df['content_age'] = current_year - df['release_year']

# %% [markdown]
# **Movie**

# %%
df['is_movie'] = df['type'].apply(lambda x: 1 if x=='Movie' else 0)

# %% [markdown]
# **Recent Content**

# %%
df['is_recent'] = df['release_year'].apply(lambda x: 1 if x>=2018 else 0)

# %% [markdown]
# **Duration**

# %%
df['duration_minutes'] = df['duration'].str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3957158811.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['duration_minutes'] = df['duration'].str.extract('(\d+)').astype(float)

# %% [markdown]
# **Rating Group**

# %%
def rating_group(r):
    if r in ['G','TV-Y']:
        return 'Kids'
    elif r in ['PG','PG-13']:
        return 'Teen'
    else:
        return 'Adult'

df['rating_group'] = df['rating'].apply(rating_group)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                      Not Available        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25        2020.0  PG-13     90 min
# 1  2021-09-24        2021.0  TV-MA  2 Seasons
# 2  2021-09-24        2021.0  TV-MA   1 Season
# 3  2021-09-24        2021.0  TV-MA   1 Season
# 4  2021-09-24        2021.0  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  content_age  is_movie  \
# 0  As her father nears the end of his life, filmm...          4.0         1
# 1  After crossing paths at a party, a Cape Town t...          3.0         0
# 2  To protect his family from a powerful drug lor...          3.0         0
# 3  Feuds, flirtations and toilet talk go down amo...          3.0         0
# 4  In a city of coaching centers known to train I...          3.0         0
#
#    is_recent  duration_minutes rating_group
# 0          1              90.0         Teen
# 1          1               2.0        Adult
# 2          1               1.0        Adult
# 3          1               1.0        Adult
# 4          1               2.0        Adult

# %% [markdown]
# # **ENCODING**

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['rating_group_encoded'] = le.fit_transform(df['rating_group'])

# %%
df[['rating_group','rating_group_encoded']].head()
# Out:
#   rating_group  rating_group_encoded
# 0         Teen                     2
# 1        Adult                     0
# 2        Adult                     0
# 3        Adult                     0
# 4        Adult                     0

# %% [markdown]
# # **SCALING**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df['content_age_scaled'] = scaler.fit_transform(df[['content_age']])

# %%
df[['content_age','content_age_scaled']].head()
# Out:
#    content_age  content_age_scaled
# 0          4.0           -0.975877
# 1          3.0           -1.240022
# 2          3.0           -1.240022
# 3          3.0           -1.240022
# 4          3.0           -1.240022

# %% [markdown]
# # **BEFORE vs AFTER**

# %%
df[['content_age','content_age_scaled']].describe()
# Out:
#        content_age  content_age_scaled
# count  8088.000000        8.088000e+03
# mean      7.694486       -2.811247e-17
# std       3.786044        1.000062e+00
# min       3.000000       -1.240022e+00
# 25%       5.000000       -7.117330e-01
# 50%       7.000000       -1.834444e-01
# 75%       9.000000        3.448442e-01
# max      20.000000        3.250431e+00

# %% [markdown]
# # **SAVE CSV**

# %%
df.to_csv("netflix_week4_feature_engineered.csv", index=False)
